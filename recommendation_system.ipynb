# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavanaAtGit/Price_Comparator_App/blob/main/recommendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sample data representing product attributes for multiple products
product_attributes = {
    'handmade_pottery': ['ceramic', 'decorative', 'kitchenware'],
    'artisanal_soap': ['natural', 'fragrant', 'skincare'],
    'handcrafted_jewelry': ['silver', 'gemstones', 'necklaces'],
    'handmade_candles': ['scented', 'decorative', 'wax'],
    'organic_skincare': ['natural', 'moisturizing', 'vegan'],
    'handcrafted_furniture': ['wood', 'rustic', 'custom-made'],
    'artisanal_cheese': ['organic', 'aged', 'gourmet'],
    'organic_wine': ['red', 'white', 'biodynamic'],
    'handmade_bags': ['fabric', 'tote', 'hand-stitched'],
    'artisanal_bread': ['whole grain', 'crusty', 'baked fresh'],
    'handwoven_rugs': ['wool', 'colorful', 'traditional'],
    'artisanal_chocolate': ['dark', 'cocoa beans', 'handcrafted'],
    'handmade_blankets': ['knit', 'cozy', 'woolen'],
    'organic_honey': ['raw', 'pure', 'nectar'],
    'handmade_journals': ['recycled paper', 'bound', 'sketching'],
    'artisanal_olive_oil': ['extra virgin', 'cold pressed', 'flavorful'],
    'handcrafted_baskets': ['woven', 'artisan', 'natural materials'],
    'organic_tea': ['herbal', 'loose leaf', 'aromatic'],
    'handmade_scarves': ['knitted', 'soft', 'winter'],
    'artisanal_jams': ['homemade', 'fruit-filled', 'preserves'],
    'handmade_soaps': ['hand-cut', 'aromatherapy', 'moisturizing'],
    'organic_spices': ['natural', 'aromatic', 'sustainable'],
    'handwoven_baskets': ['rattan', 'decorative', 'storage'],
    'artisanal_pasta': ['hand-rolled', 'artisan', 'authentic'],
    'handmade_beaded_jewelry': ['beads', 'colorful', 'unique'],
    'organic_eggs': ['free-range', 'pasture-raised', 'nutrient-rich'],
    'handmade_pillows': ['embroidered', 'decorative', 'cotton'],
    'artisanal_pickles': ['homemade', 'crunchy', 'brined'],
    'organic_vegetables': ['locally grown', 'fresh', 'seasonal'],
    'handmade_notebooks': ['hand-bound', 'recycled', 'journaling'],
    'artisanal_sauces': ['small batch', 'gourmet', 'flavorful'],
    'organic_juice': ['cold-pressed', 'fresh', 'natural'],
    'handmade_baskets': ['woven', 'natural fibers', 'functional'],
    'artisanal_cookies': ['homemade', 'baked fresh', 'indulgent'],
    'handcrafted_brooms': ['natural bristles', 'traditional', 'durable'],
    'organic_grains': ['whole', 'locally sourced', 'nutritious'],
    'handmade_earrings': ['beaded', 'dangling', 'fashionable'],
    'artisanal_salsa': ['handcrafted', 'spicy', 'authentic'],
    'organic_jams': ['fruit preserves', 'homemade', 'all-natural'],
    'handcrafted_bowls': ['wooden', 'turned', 'artistic'],
    'artisanal_butter': ['grass-fed', 'whipped', 'creamy'],
    'handmade_brooms': ['broomcorn', 'decorative', 'functional'],
    'organic_nuts': ['raw', 'unprocessed', 'nutrient-dense'],
    'handmade_necklaces': ['beaded', 'statement', 'unique'],
    'artisanal_mustard': ['gourmet', 'homemade', 'bold'],
    'organic_syrup': ['maple', 'pure', 'natural'],
    'handwoven_blankets': ['wool', 'cozy', 'heirloom'],
    'artisanal_crackers': ['handmade', 'gourmet', 'crispy'],
    'handcrafted_candles': ['beeswax', 'aromatic', 'long-lasting'],
    'organic_milk': ['grass-fed', 'hormone-free', 'pasteurized'],
    'handmade_bracelets': ['beaded', 'hand-crafted', 'stylish'],
    'artisanal_pie': ['homemade', 'flaky crust', 'seasonal fruit'],
    'organic_pasta': ['whole wheat', 'artisanal', 'nutty'],
    'handcrafted_chairs': ['wood', 'carved', 'ergonomic'],
    'artisanal_biscuits': ['homemade', 'buttery', 'delicious'],
    'handwoven_scarves': ['silk', 'lightweight', 'textured'],
    'organic_cheese': ['artisanal', 'aged', 'farm-fresh'],
    'handmade_spoons': ['wooden', 'carved', 'kitchen utensils'],
    'artisanal_honey': ['local', 'wildflower', 'golden'],
    'handcrafted_belts': ['leather', 'embossed', 'sturdy'],
    'organic_granola': ['whole grain', 'nutty', 'toasted'],
    'handmade_pasta': ['fresh', 'egg', 'artisanal'],
    'artisanal_granola': ['homemade', 'oats', 'nutty'],
    'handcrafted_rugs': ['wool', 'intricate', 'colorful'],
    'organic_bread': ['whole grain', 'sourdough', 'artisanal'],
    'handmade_pies': ['fruit-filled', 'flaky crust', 'baked fresh'],
    'artisanal_broth': ['homemade', 'slow-cooked', 'flavorful'],
    'handwoven_placemats': ['natural fibers', 'weave', 'durable'],
    'organic_salsa': ['fresh', 'chunky', 'spicy'],
    'handcrafted_dolls': ['cloth', 'hand-sewn', 'whimsical'],
    'artisanal_candles': ['soy wax', 'fragrant', 'hand-poured'],
    'handmade_ornaments': ['clay', 'painted', 'festive'],
    'organic_tomatoes': ['heirloom', 'vine-ripened', 'juicy'],
    'handwoven_bags': ['rattan', 'tote', 'bohemian'],
    'artisanal_gelato': ['homemade', 'creamy', 'flavors'],
    'handcrafted_chocolates': ['truffles', 'assorted', 'handmade'],
    'organic_chips': ['potato', 'lightly salted', 'crispy'],
    'handmade_mugs': ['ceramic', 'wheel-thrown', 'cozy'],
    'artisanal_jelly': ['homemade', 'fruit preserves', 'sweet'],
    'handwoven_bowls': ['rattan', 'decorative', 'functional'],
    'organic_herbs': ['fresh', 'fragrant', 'culinary'],
    'handmade_vases': ['pottery', 'hand-thrown', 'decorative'],
    'artisanal_butterflies': ['paper', 'colorful', 'mobile'],
    'handcrafted_pillows': ['embroidered', 'decorative', 'cozy'],
    'organic_juices': ['cold-pressed', 'fresh', 'nutritious'],
    'handmade_toys': ['wooden', 'educational', 'hand-painted'],
    'artisanal_cookies': ['homemade', 'buttery', 'chocolate chip'],
    'handwoven_belts': ['leather', 'braided', 'sturdy'],
    'organic_cookies': ['whole grain', 'sweetened with honey', 'nutty'],
    'handcrafted_spoons': ['wooden', 'carved', 'serving'],
    'artisanal_grains': ['whole', 'organic', 'locally sourced'],
    'handmade_sculptures': ['clay', 'figurative', 'artistic'],
    'organic_butter': ['grass-fed', 'unsalted', 'wholesome'],
    'handwoven_baskets': ['seagrass', 'coastal', 'functional'],
    'artisanal_broccoli': ['organic', 'fresh', 'nutrient-rich'],
    'handcrafted_jams': ['fruit preserves', 'homemade', 'artisanal'],
    'organic_soy_milk': ['non-GMO', 'unsweetened', 'creamy'],
    'handmade_brushes': ['natural bristles', 'wooden handle', 'painting'],
    'artisanal_spices': ['ground', 'aromatic', 'exotic'],
    'handwoven_napkins': ['cotton', 'block-printed', 'absorbent'],
    'organic_dried_fruit': ['unsulfured', 'sweet', 'nutritious'],
    'handmade_socks': ['woolen', 'cozy', 'hand-knit'],
    'artisanal_syrup': ['maple', 'amber', 'natural'],
    'handcrafted_pens': ['wood', 'hand-turned', 'refillable'],
    'organic_biscuits': ['whole grain', 'buttery', 'crispy'],
    'handmade_shawls': ['knitted', 'soft', 'versatile'],
    'artisanal_spoons': ['wooden', 'hand-carved', 'serving'],
    'handcrafted_chocolates': ['ganache-filled', 'truffles', 'hand-dipped'],
    'organic_snacks': ['nuts', 'dried fruit', 'healthy'],
    'handwoven_scarves': ['silk', 'lightweight', 'luxurious'],
    'artisanal_salad_dressing': ['vinaigrette', 'homemade', 'tangy'],
    'handmade_butterflies': ['paper', 'decorative', 'colorful'],
    'organic_pie': ['seasonal fruit', 'whole grain crust', 'flaky'],
    'handcrafted_soap': ['fragrant', 'moisturizing', 'hand-cut'],
    'artisanal_muffins': ['homemade', 'blueberry', 'freshly baked'],
    'handwoven_blankets': ['cotton', 'soft', 'cozy'],
    'organic_pasta_sauce': ['tomato basil', 'fresh', 'homemade'],
    'handmade_brooches': ['beaded', 'vintage', 'hand-crafted'],
    'artisanal_pesto': ['fresh basil', 'homemade', 'tangy'],
    'handcrafted_birdhouses': ['wooden', 'painted', 'functional'],
    'organic_hummus': ['chickpea', 'garlicky', 'creamy'],
    'handmade_truffles': ['chocolate', 'ganache', 'decadent'],
    'artisanal_ice_cream': ['homemade', 'creamy', 'flavors'],
    'handcrafted_vases': ['pottery', 'wheel-thrown', 'unique'],
    'organic_breadsticks': ['whole grain', 'crunchy', 'sesame'],
    'handwoven_pillows': ['cotton', 'embroidered', 'cozy'],
    'artisanal_cookies': ['homemade', 'chewy', 'chocolate chunk'],
    'handmade_bows': ['satin', 'ribbon', 'festive'],
    'organic_tofu': ['non-GMO', 'firm', 'versatile'],
    'handcrafted_jewelry_boxes': ['wooden', 'hand-carved', 'elegant'],
    'artisanal_hummus': ['chickpea', 'creamy', 'spiced'],
    'handwoven_bread_baskets': ['seagrass', 'coastal', 'functional'],
    'organic_lotion': ['lavender', 'moisturizing', 'natural'],
    'handmade_greeting_cards': ['hand-painted', 'artistic', 'personalized'],
    'artisanal_scones': ['homemade', 'buttery', 'flaky'],
    'handcrafted_beaded_jewelry': ['necklaces', 'bracelets', 'earrings'],
    'organic_flour': ['whole wheat', 'stone-ground', 'nutty'],
    'handwoven_trays': ['rattan', 'decorative', 'serving'],
    'artisanal_tea': ['loose leaf', 'fragrant', 'organic'],
    'handmade_sweaters': ['wool', 'cozy', 'hand-knit'],
    'organic_chocolate': ['dark', 'fair-trade', 'decadent'],
    'handcrafted_brooches': ['beaded', 'vintage', 'unique'],
    'artisanal_bath_bombs': ['fizzy', 'fragrant', 'relaxing'],
    'handwoven_table_runners': ['cotton', 'embroidered', 'festive'],
    'organic_candles': ['soy wax', 'aromatic', 'clean-burning'],
    'handmade_curtains': ['fabric', 'printed', 'decorative'],
    'artisanal_balsamic_vinegar': ['aged', 'balsamic', 'imported'],
    'handcrafted_ceramics': ['pottery', 'wheel-thrown', 'functional'],
    'organic_pancake_mix': ['whole grain', 'maple', 'fluffy'],
    'handwoven_towels': ['cotton', 'absorbent', 'soft'],
    'artisanal_granola_bars': ['homemade', 'nutty', 'chewy'],
    'handmade_sweatshirts': ['cotton', 'cozy', 'hand-dyed'],
}


# Sample data representing user purchase history for multiple users
user_purchase_history = {
    'user1': ['handmade_pottery', 'artisanal_soap', 'handcrafted_jewelry'],
    'user2': ['handmade_candles', 'organic_skincare'],
    'user3': ['handcrafted_furniture', 'artisanal_cheese'],
    'user4': ['handmade_bags', 'handcrafted_jewelry', 'handwoven_rugs', 'artisanal_chocolate'],
    'user5': ['artisanal_chocolate', 'organic_wine'],
    'user6': ['handmade_candles', 'handwoven_rugs'],
    'user7': ['organic_skincare', 'handcrafted_jewelry'],
    'user8': ['handmade_pottery', 'artisanal_bread', 'organic_wine', 'handcrafted_furniture'],
    'user9': ['handcrafted_furniture', 'artisanal_cheese', 'handmade_candles', 'handmade_bags'],
    'user10': ['artisanal_chocolate', 'handwoven_rugs'],
    'user11': ['handmade_bags', 'handcrafted_furniture', 'organic_skincare', 'handcrafted_jewelry'],
    'user12': ['handmade_pottery', 'artisanal_soap', 'handcrafted_jewelry'],
    'user13': ['handmade_candles', 'organic_skincare', 'handwoven_rugs'],
    'user14': ['handcrafted_furniture', 'organic_wine'],
    'user15': ['handmade_bags', 'handcrafted_jewelry']
}


# Function to recommend popular products based on purchase history
def recommend_popular_products(user_purchase_history, num_recommendations=5):
    product_counts = {}
    # Count the number of times each product appears in the purchase history
    for purchases in user_purchase_history.values():
        for product in purchases:
            product_counts[product] = product_counts.get(product, 0) + 1
    # Sort products by their purchase count in descending order
    popular_products = sorted(product_counts.items(), key=lambda x: x[1], reverse=True)
    # Return top N popular products as recommendations
    return [product[0] for product in popular_products[:num_recommendations]]

# Get user login ID from input
login_id = input("Enter your login ID: ")

# Get recommendations for the entered login ID
user_recommendations = recommend_popular_products(user_purchase_history)
print(f"Recommendations for {login_id}: {user_recommendations}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-cd2b9572d143> in <cell line: 191>()
#     189
#     190 # Get user login ID from input
# --> 191 login_id = input("Enter your login ID: ")
#     192
#     193 # Get recommendations for the entered login ID
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
# from collections import defaultdict
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import linear_kernel

# Sample data representing user purchase history for multiple users
product_categories = {
    'pottery': ['handmade_pottery', 'handmade_vases', 'handmade_mugs', 'handmade_spoons'],
    'soap': ['artisanal_soap', 'handmade_soaps', 'handcrafted_soap', 'handcrafted_bath_bombs'],
    'jewelry': ['handcrafted_jewelry', 'handmade_beaded_jewelry', 'handmade_beaded_jewelry', 'handmade_bracelets'],
    'candles': ['handmade_candles', 'handcrafted_candles', 'artisanal_candles', 'handcrafted_chocolates'],
    'skincare': ['organic_skincare', 'handmade_skincare', 'artisanal_butter', 'organic_lotion'],
    'furniture': ['handcrafted_furniture', 'handcrafted_chairs', 'handcrafted_baskets', 'handcrafted_brooms'],
    'cheese': ['artisanal_cheese', 'organic_cheese', 'artisanal_butter', 'organic_butter'],
    'wine': ['organic_wine', 'artisanal_wine', 'organic_juice', 'artisanal_ice_cream'],
    'bags': ['handmade_bags', 'handwoven_bags', 'handwoven_rugs', 'handwoven_baskets'],
    'chocolate': ['artisanal_chocolate', 'handcrafted_chocolates', 'organic_chocolate', 'handmade_truffles'],
    # Add more categories as needed
}

user_purchase_history = {
    'user1': {'handmade_pottery': 1, 'artisanal_soap': 1, 'handcrafted_jewelry': 1},
    'user2': {'handmade_candles': 1, 'organic_skincare': 1},
    'user3': {'handcrafted_furniture': 1, 'artisanal_cheese': 1},
    'user4': {'handmade_bags': 1, 'handcrafted_jewelry': 1, 'handwoven_rugs': 1, 'artisanal_chocolate': 1},
    'user5': {'artisanal_chocolate': 1, 'organic_wine': 1},
    'user6': {'handmade_candles': 1, 'handwoven_rugs': 1},
    'user7': {'organic_skincare': 1, 'handcrafted_jewelry': 1},
    'user8': {'handmade_pottery': 1, 'artisanal_bread': 1, 'organic_wine': 1, 'handcrafted_furniture': 1},
    'user9': {'handcrafted_furniture': 1, 'artisanal_cheese': 1, 'handmade_candles': 1, 'handmade_bags': 1},
    'user10': {'artisanal_chocolate': 1, 'handwoven_rugs': 1},
    'user11': {'handmade_bags': 1, 'handcrafted_furniture': 1, 'organic_skincare': 1, 'handcrafted_jewelry': 1},
    'user12': {'handmade_pottery': 1, 'artisanal_soap': 1, 'handcrafted_jewelry': 1},
    'user13': {'handmade_candles': 1, 'organic_skincare': 1, 'handwoven_rugs': 1},
    'user14': {'handcrafted_furniture': 1, 'organic_wine': 1},
    'user15': {'handmade_bags': 1, 'handcrafted_jewelry': 1}
}
def recommend_products_by_category(user_purchase_history, num_recommendations=5):
    product_counts = {}
    # Count the number of times each product appears in the purchase history
    for purchases in user_purchase_history.values():
        for product in purchases:
            product_counts[product] = product_counts.get(product, 0) + 1

    category_counts = {}
    # Count the number of times each category appears in the purchase history
    for purchases in user_purchase_history.values():
        for product in purchases:
            for category, products in product_categories.items():
                if product in products:
                    category_counts[category] = category_counts.get(category, 0) + 1

    # Sort categories by their purchase count in descending order
    popular_categories = sorted(category_counts.items(), key=lambda x: x[1], reverse=True)
    # Return top N popular categories along with their products as recommendations
    recommendations = {}
    for category, count in popular_categories[:num_recommendations]:
        category_products = [product for product in product_categories[category] if product_counts.get(product, 0) > 1]
        recommendations[category] = category_products
    return recommendations

# Get user login ID from input
login_id = input("Enter your login ID: ")

# Get recommendations for the entered login ID
user_recommendations = recommend_popular_products(user_purchase_history)
category_recommendations = recommend_products_by_category(user_purchase_history)

print(f"Recommendations for {login_id}:")
print("Popular Products:", user_recommendations)
print("Category-based Recommendations:", category_recommendations)
# Out:
# Enter your login ID: user2
# Recommendations for user2:
# Popular Products: ['handcrafted_jewelry', 'handcrafted_furniture', 'handmade_candles', 'organic_skincare', 'handmade_bags']
# Category-based Recommendations: {'bags': ['handmade_bags', 'handwoven_rugs'], 'jewelry': ['handcrafted_jewelry'], 'furniture': ['handcrafted_furniture'], 'candles': ['handmade_candles'], 'skincare': ['organic_skincare']}

# %% [markdown]
# # New Section
